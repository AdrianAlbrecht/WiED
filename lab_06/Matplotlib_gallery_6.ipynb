# %%
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# Fixing random state for reproducibility
np.random.seed(19990802)

# fake up some data
spread = np.random.rand(50) * 100
center = np.ones(25) * 80
flier_high = np.random.rand(10) * 100 + 100
flier_low = np.random.rand(10) * -100
data = np.concatenate((spread, center, flier_high, flier_low))

fig2, ax2 = plt.subplots()
ax2.set_title('Notched boxes', fontsize=30)
plt.xlabel('Some random values', fontsize=15)
plt.ylabel('Some other random values', fontsize=15)
ax2.boxplot(data, notch=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fbac9d35670>,
#   <matplotlib.lines.Line2D at 0x7fbac9d35910>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fbac9d35bb0>,
#   <matplotlib.lines.Line2D at 0x7fbac9d35e50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fbac9d353d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fbac9cc4130>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fbac9cc43d0>],
#  'means': []}
